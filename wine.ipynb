# %%
import pandas as pd
red_wine = pd.read_csv('winequality-red.csv',sep=';')
white_wine=pd.read_csv('winequality-white.csv',sep=None)
red_wine
# Out:
# C:\Users\trifo\AppData\Local\Temp\ipykernel_4844\621513639.py:3: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support sep=None with delim_whitespace=False; you can avoid this warning by specifying engine='python'.
#   white_wine=pd.read_csv('winequality-white.csv',sep=None)
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# ...

# %%
#red_wine.head(10)

# %%
#display(red_wine.head(10))
#display(red_wine.tail(10))

# %% [markdown]
# why i cannot see them both,when i print them in the same cell?

# %% [markdown]
# how can we select bot values to be changed simultaneously?

# %%
#red_wine.info()

# %%
#red_wine.shape

# %%
# observe if there are missing values
#red_wine.iloc[ : , 1 : 12].isna().sum()

# %%
#check for Descriptive Statistics
#red_wine.describe()

# %%
#white_wine=pd.read_csv('winequality-white.csv',sep=';')

#white_wine.shape

# %%
#white_wine.iloc[ : ,1:12].isna().sum()

# %%
# we are creating a new column called "quality_label", we define a range and associate that range with a label
#red_wine['quality_label'] = red_wine['quality'].apply(lambda value: 'low'
#if value <= 5 else 'medium'
#if value <= 7 else 'high')

red_wine['quality_label'] = red_wine['quality'].apply(lambda x: 'low'
if x <= 5 else 'medium'
if x <= 7 else 'high')

## here we are transforming these labels into categrical data type (specific to pandas) instead of simple string
red_wine['quality_label'] = pd.Categorical(red_wine['quality_label'],categories=['low', 'medium', 'high'])

red_wine
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %% [markdown]
# i used this code:
# df['category']=df['age'].apply(lambda x: 'Adult' if x>=18 else 'Child')

# %%
white_wine['quality_label'] = white_wine['quality'].apply(lambda x: 'low'
if x <= 5 else 'medium'
if x <= 7 else 'high')

white_wine['quality_label']= pd.Categorical(white_wine['quality_label'],
categories=['low', 'medium', 'high'])
white_wine.tail(10)
white_wine
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.0              0.27         0.36            20.7      0.045
# 1               6.3              0.30         0.34             1.6      0.049
# 2               8.1              0.28         0.40             6.9      0.050
# 3               7.2              0.23         0.32             8.5      0.058
# 4               7.2              0.23         0.32             8.5      0.058
# ...             ...               ...          ...             ...        ...
# 4893            6.2              0.21         0.29             1.6      0.039
# 4894            6.6              0.32         0.36             8.0      0.047
# 4895            6.5              0.24         0.19             1.2      0.041
# 4896            5.5              0.29         0.30             1.1      0.022
# 4897            6.0              0.21         0.38             0.8      0.020
#
# ...

# %%
red_wine['wine_type'] = 'red'
white_wine['wine_type'] = 'white'
wines = pd.concat([red_wine, white_wine])

#re-shuffle records just to randomize data points
wines = wines.sample(frac=1, random_state=42).reset_index(drop=True)
wines
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.0              0.17         0.74           12.80      0.045
# 1               7.7              0.64         0.21            2.20      0.077
# 2               6.8              0.39         0.34            7.40      0.020
# 3               6.3              0.28         0.47           11.20      0.040
# 4               7.4              0.35         0.20           13.90      0.054
# ...             ...               ...          ...             ...        ...
# 6492            7.6              0.32         0.58           16.75      0.050
# 6493            5.6              0.28         0.27            3.90      0.043
# 6494            6.4              0.37         0.20            5.60      0.117
# 6495            6.5              0.26         0.50            8.00      0.051
# 6496            7.2              0.62         0.06            2.70      0.077
#
# ...

# %%
white_wine1=white_wine[['residual sugar', 'total sulfur dioxide','sulphates','alcohol','volatile acidity','quality']]
white_wine1=white_wine1.describe()
red_wine1=red_wine[['residual sugar', 'total sulfur dioxide','sulphates','alcohol','volatile acidity','quality']]
red_wine1=red_wine1.describe()
Concat_table = pd.concat([red_wine1, white_wine1],axis=1)
pd.options.display.float_format = "{:,.2f}".format
Concat_table
# Out:
#        residual sugar  total sulfur dioxide  sulphates  alcohol  \
# count        1,599.00              1,599.00   1,599.00 1,599.00
# mean             2.54                 46.47       0.66    10.42
# std              1.41                 32.90       0.17     1.07
# min              0.90                  6.00       0.33     8.40
# 25%              1.90                 22.00       0.55     9.50
# 50%              2.20                 38.00       0.62    10.20
# 75%              2.60                 62.00       0.73    11.10
# max             15.50                289.00       2.00    14.90
#
#        volatile acidity  quality  residual sugar  total sulfur dioxide  \
# count          1,599.00 1,599.00        4,898.00              4,898.00
# mean               0.53     5.64            6.39                138.36
# std                0.18     0.81            5.07                 42.50
# min                0.12     3.00            0.60                  9.00
# ...

# %%
white_wine1.style.set_caption("White Wine Statistics")
# Out:
# <style type="text/css">
# </style>
# <table id="T_6e56f">
#   <caption>White Wine Statistics</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6e56f_level0_col0" class="col_heading level0 col0" >residual sugar</th>
#       <th id="T_6e56f_level0_col1" class="col_heading level0 col1" >total sulfur dioxide</th>
#       <th id="T_6e56f_level0_col2" class="col_heading level0 col2" >sulphates</th>
#       <th id="T_6e56f_level0_col3" class="col_heading level0 col3" >alcohol</th>
#       <th id="T_6e56f_level0_col4" class="col_heading level0 col4" >volatile acidity</th>
#       <th id="T_6e56f_level0_col5" class="col_heading level0 col5" >quality</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6e56f_level0_row0" class="row_heading level0 row0" >count</th>
#       <td id="T_6e56f_row0_col0" class="data row0 col0" >4898.000000</td>
#       <td id="T_6e56f_row0_col1" class="data row0 col1" >4898.000000</td>
# ...

# %%
Concat_table
#Volatile acidity:white<red(red wines are fermented in closed baches,while the white are in open,contributes to the smell and taste of vinegar in wine)
#Crushed grapes are then placed into fermentation tanks where yeast grows and consumes the natural sugars, turning into alcohol. 
#Most importantly for red wine production, the skins are left on, adding the colour, flavours and textures we associate with red wines.
#the amount of acetic acid in wine, which at too high of levels can lead to an unpleasant, vinegar taste
#Sulfates :red>white(potential headaches which also is just a rumour)
#Residual sugar: typically refers to the sugar remaining after fermentation stops:white>>red(in order to be ballanced the taste,
#because white wine is more acid,we need more sugar)
#Alcohol: is very low in both cases.normally in the south white wines have around 13-14 where red about 14-15
# Out:
#        residual sugar  total sulfur dioxide  sulphates  alcohol  \
# count        1,599.00              1,599.00   1,599.00 1,599.00
# mean             2.54                 46.47       0.66    10.42
# std              1.41                 32.90       0.17     1.07
# min              0.90                  6.00       0.33     8.40
# 25%              1.90                 22.00       0.55     9.50
# 50%              2.20                 38.00       0.62    10.20
# 75%              2.60                 62.00       0.73    11.10
# max             15.50                289.00       2.00    14.90
#
#        volatile acidity  quality  residual sugar  total sulfur dioxide  \
# count          1,599.00 1,599.00        4,898.00              4,898.00
# mean               0.53     5.64            6.39                138.36
# std                0.18     0.81            5.07                 42.50
# min                0.12     3.00            0.60                  9.00
# ...

# %%
import matplotlib.pyplot as plt

# Pie chart, where the slices will be ordered and plotted counter-clockwise:
labels = 'Red Wines', 'White Wines',
sizes = [1599, 4898]
explode = (0, 0.1)  # only "explode" the 2nd slice (i.e. 'White Wines')

fig1, ax1 = plt.subplots()
ax1.pie(sizes,explode=explode, labels=labels, autopct='%1.1f%%',
        shadow=True, startangle=90)
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

plt.show()

# %%
#df_white=white_wine.value_counts("quality_label")
#df_white.plot.bar(color= '#808080')
#plt.title('White wine')

# %%
#white_wine.value_counts("quality_label")

# %%
#white_wine.index

# %%
# Check the strength of the correlation among the variables.
# WHITE WINE
#import seaborn as sns
#plt.figure(figsize=(12,8))
#ax = sns.heatmap(white_wine.corr(), cmap='Greens', annot=True)
#plt.show()

# %%
#white_wine.corr()[['quality']].sort_values(by='quality', ascending = False)

# %% [markdown]
# Conclusion
# As alcohol level increase ==> Quality increases
# As density decreases ==> Quality increases
# As chlorides level decreases ==> Quality increases
# As the volatile acidity decreases ==> Quality increases

# %% [markdown]
# alcohol,density,chlorides and volatile acidity influence the quality of white wine in  order.
# Output : Correlation Heatmap
# why figsize=(12,8)?

# %%
#g = sns.PairGrid(white_wine[['alcohol','density','chlorides','volatile acidity']])
#g = g.map_upper(sns.kdeplot, cmap='YlGnBu', shade=True, thresh=0.05)
#g = g.map_diag(plt.hist, color='#6cbd5e')
#g = g.map_lower(sns.scatterplot, color='#b8e0b1', edgecolor='k')

#g.fig.tight_layout()
#g.fig.suptitle('Relationship')
#plt.subplots_adjust(top=0.9)

# %%
# Plot JointPlot
# alcohol ~  density

#g = sns.JointGrid(x='alcohol', y='density', data=white_wine)
#g = g.plot_joint(sns.regplot, color='#eb447e')
#g = g.plot_marginals(sns.displot, color='#fc7f03')

# %%
# Plot JointPlot
# density ~ residual sugar

#g = sns.JointGrid(x='density', y='residual sugar', data=white_wine)
#g = g.plot_joint(sns.regplot, color='#eb447e')
#g = g.plot_marginals(sns.distplot, color='#fc7f03')

# %%
# Plot JointPlot
# free sulfur dioxide ~ total sulfur dioxide

#g = sns.JointGrid(x='free sulfur dioxide', y='total sulfur dioxide', data=white_wine)
#g = g.plot_joint(sns.regplot, color='#eb447e')
#g = g.plot_marginals(sns.distplot, color='#fc7f03')

# %%
import seaborn as sns
#sns.boxplot(x='quality_label', y='alcohol', data=white_wine)

# %%
#sns.boxplot(x='quality_label', y='pH', data=white_wine)

# %%
#########    RED WINE    #########
#import seaborn as sns
#plt.figure(figsize=(12,8))
#sns.heatmap(red_wine.corr(), cmap='Greens', annot=True)
#plt.show()

# %%
#red_wine.corr()[['quality']].sort_values(by='quality', ascending = False)

# alcohol,volatile acidity,sulphates and citric acid influence the quality of red wine in  order. 
# the relationship among the important variables

# %% [markdown]
# Conclusion
# As alcohol level increase ==> Quality increases
# As the volatile acidity decreases ==> Quality increases
# As sulphate decreases ==> Quality increases
# As citric acid level increase ==> Quality increases

# %%
#g = sns.PairGrid(red_wine[['alcohol','volatile acidity','sulphates','citric acid']])
#g = g.map_upper(sns.kdeplot, cmap='YlGnBu', shade=True, thresh=0.05)
#g = g.map_diag(plt.hist, color='#6cbd5e')
#g = g.map_lower(sns.scatterplot, color='#b8e0b1', edgecolor='k')
#
#g.fig.tight_layout()
#g.fig.suptitle('Relationship')
#plt.subplots_adjust(top=0.9)

# %%
#g = sns.JointGrid(x='alcohol', y='density', data=red_wine)
#g = g.plot_joint(sns.regplot, color='#eb447e')

# %%
# Plot JointPlot
# fixed acidity~density

#g = sns.JointGrid(x='fixed acidity', y='density', data=red_wine)
#g = g.plot_joint(sns.regplot, color='#eb447e')
#g = g.plot_marginals(sns.distplot, color='#fc7f03')

# %%
# Plot JointPlot
# fixed acidity~citric acid

#g = sns.JointGrid(x='fixed acidity', y='citric acid', data=red_wine)
#g = g.plot_joint(sns.regplot, color='#eb447e')
#g = g.plot_marginals(sns.distplot, color='#fc7f03')

# %% [markdown]
# Vinho Verde P.O.P. comprises 21,000 hectares of vineyards, 129,000 vineyards, 47 grape varieties, 25,500 wine producers and 600 bottlers, who produce around 85 million litres of wine annually and export it to 80 countries.

# %% [markdown]
# Another reason for the fruity freshness is controlled malolactic fermentation, in which malolactic acid is converted into lactic acid and carbon dioxide and the acid is degraded altogether.

# %% [markdown]
#  the ideal white wine Vinho Verde P.O.P. has a taste of citrus and green apples, combined with the aroma of rocket, kiwi, passion fruit, pineapple and minerals.

# %% [markdown]
# Vinho Verde is a product of several grape varieties, including Alvarinho, Arinto, Avesso, Azal, Batoca, Loureiro and Trajadura, among others. Meanwhile, however, Vinho Verde is also produced using grapes from a single variety, for example Loureiro or Alvarinho. These wines are usually more complex with exotic fruit aromas and have less acidity and more residual sugars.

# %% [markdown]
# 1.Volatile acidity:white<red(red wines are fermented in closed baches,while the white are in open,contributes to the smell and taste of vinegar in wine)
# Crushed grapes are then placed into fermentation tanks where yeast grows and consumes the natural sugars, turning into alcohol.
# Most importantly for red wine production, the skins are left on, adding the colour, flavours and textures we associate with red wines.
# the amount of acetic acid in wine, which at too high of levels can lead to an unpleasant, vinegar taste
# 2.Sulfates :red>white(potential headaches which also is just a rumour)
# 3.Residual sugar: typically refers to the sugar remaining after fermentation stops:white>>red(in order to be ballanced the taste,
# because white wine is more acid,we need more sugar)
# #Alcohol: is very low in both cases.normally in the south white wines have around 13-14 where red about 14-15.

# %%
plt.figure(figsize=(12,8))
sns.countplot(wines.quality, hue=wines.wine_type)
# Out:
# c:\Users\trifo\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='quality', ylabel='count'>

# %%
sns.pairplot(data=wines,kind='scatter',diag_kind='kde',hue='wine_type')
